# %%
import simpy
import random
import pandas as pd

# %%
class Consola:
    def __init__(self, env, id, tipo, juegos_disponibles):
        self.env = env
        self.id = id
        self.tipo = tipo
        self.juegos_disponibles = juegos_disponibles
        self.recurso = simpy.Resource(env, capacity=1)  # Solo 1 cliente por consola

# %%
class SistemaAlquiler:
    def __init__(self, env, num_consolas_xbox, num_consolas_ps):
        self.env = env
        self.recursos = {
            'ps': [Consola(env, f'ps_{i+1}', 'ps', ['fifa', 'call_of_duty']) for i in range(num_consolas_ps)],
            'xbox': [Consola(env, f'xbox_{i+1}', 'xbox', ['fifa', 'call_of_duty']) for i in range(num_consolas_xbox)]
        }
        self.clientes = []

    def agregar_cliente(self, tipo_consola, juego, paciente):
        cliente = Cliente(self.env, len(self.clientes)+1, self, tipo_consola, juego, paciente)
        self.clientes.append(cliente)

# %%
class Cliente:
    def __init__(self, env, id, sistema, tipo_consola, juego, paciente):
        self.env = env
        self.id = id
        self.sistema = sistema
        self.tipo_consola = tipo_consola
        self.juego = juego
        self.paciente = paciente
        self.eventos = pd.DataFrame()
        self.costo = 0  # Costo inicial
        self.atendido = False  # Flag para saber si fue atendido
        self.env.process(self.proceso())

    def registrar_evento(self, evento):
        print(f"{self.env.now}: Cliente {self.id} - {evento}")
        self.eventos = pd.concat([self.eventos, pd.DataFrame({
            "id": [self.id],
            "evento": [evento],
            "time": [self.env.now]
        })])

    def proceso(self):
        self.registrar_evento(f"LLEGA - Quiere jugar en la consola {self.tipo_consola} con el juego {self.juego}")
        
        # Verificación de consolas disponibles
        disponible = False
        consolas = self.sistema.recursos[self.tipo_consola]

        for consola in consolas:
            if consola.recurso.count < consola.recurso.capacity:
                # Si la consola está disponible
                disponible = consola
                break
        
        if disponible:
            self.registrar_evento(f"Consola {disponible.id} ESTÁ DISPONIBLE para {self.tipo_consola} con el juego {self.juego}")
            
            with disponible.recurso.request() as req:
                yield req
                self.registrar_evento(f"COMIENZA JUEGO en {disponible.id}")
                tiempo_juego = 60  # 1 hora de juego
                yield self.env.timeout(tiempo_juego)
                self.registrar_evento(f"TERMINA JUEGO en {disponible.id}")
                
                # El cliente paga la hora que jugó
                self.costo += 1  # Pago por una hora de juego
                self.registrar_evento(f"Cliente {self.id} PAGA 1 HORA")
                
                # Decisión de si el cliente se queda otra hora
                if self.paciente and random.choice([True, False]):  # Aleatorio si decide quedarse
                    self.registrar_evento(f"Cliente {self.id} DECIDE QUEDARSE UNA HORA MÁS")
                    yield self.env.timeout(60)  # Tiempo adicional de 1 hora
                    self.costo += 1  # Agregar el pago por la segunda hora
                    self.registrar_evento(f"Cliente {self.id} PAGA OTRA HORA. TOTAL = {self.costo} HORA(S)")

                # Marcar como atendido
                self.atendido = True
        else:
            self.registrar_evento(f"SE VA POR FALTA DE CONSOLA DISPONIBLE - {self.tipo_consola} con el juego {self.juego}")

# %%
# Simulación
env = simpy.Environment()

# Puedes cambiar la cantidad de consolas en este punto
num_consolas_xbox = 2  # Número de consolas Xbox
num_consolas_ps = 2  # Número de consolas PS

# Crear el sistema de alquiler con las consolas dinámicas
sistema = SistemaAlquiler(env, num_consolas_xbox, num_consolas_ps)
random.seed(42)

# %%
# Crear el proceso de nuevos clientes que llegan aleatoriamente
def crear_nuevos_clientes(env, sistema):
    while True:
        yield env.timeout(random.randint(1, 5))  # Los clientes llegan cada entre 0 y 5 minutos

        # Generar aleatoriamente el tipo de consola y juego
        tipo_consola = random.choice(['ps', 'xbox'])
        if tipo_consola == 'ps':
            juego = random.choice(['fifa', 'call_of_duty'])  # Aleatorio para PS
        else:
            juego = random.choice(['fifa', 'call_of_duty'])  # Aleatorio para Xbox
        
        paciente = random.choice([True, False])  # Puede esperar o no
        
        sistema.agregar_cliente(tipo_consola, juego, paciente)

# Iniciar el proceso de nuevos clientes
env.process(crear_nuevos_clientes(env, sistema))

# Correr simulación durante 12 horas (720 minutos)
env.run(until=60 * 12)
# Out:
# 1: Cliente 1 - LLEGA - Quiere jugar en la consola ps con el juego call_of_duty
# 1: Cliente 1 - Consola ps_1 ESTÁ DISPONIBLE para ps con el juego call_of_duty
# 1: Cliente 1 - COMIENZA JUEGO en ps_1
# 3: Cliente 2 - LLEGA - Quiere jugar en la consola ps con el juego fifa
# 3: Cliente 2 - Consola ps_2 ESTÁ DISPONIBLE para ps con el juego fifa
# 3: Cliente 2 - COMIENZA JUEGO en ps_2
# 8: Cliente 3 - LLEGA - Quiere jugar en la consola xbox con el juego fifa
# 8: Cliente 3 - Consola xbox_1 ESTÁ DISPONIBLE para xbox con el juego fifa
# 8: Cliente 3 - COMIENZA JUEGO en xbox_1
# 9: Cliente 4 - LLEGA - Quiere jugar en la consola ps con el juego fifa
# 9: Cliente 4 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego fifa
# 14: Cliente 5 - LLEGA - Quiere jugar en la consola ps con el juego call_of_duty
# 14: Cliente 5 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego call_of_duty
# 18: Cliente 6 - LLEGA - Quiere jugar en la consola xbox con el juego fifa
# 18: Cliente 6 - Consola xbox_2 ESTÁ DISPONIBLE para xbox con el juego fifa
# 18: Cliente 6 - COMIENZA JUEGO en xbox_2
# 22: Cliente 7 - LLEGA - Quiere jugar en la consola xbox con el juego call_of_duty
# 22: Cliente 7 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego call_of_duty
# 24: Cliente 8 - LLEGA - Quiere jugar en la consola xbox con el juego fifa
# 24: Cliente 8 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego fifa
# 28: Cliente 9 - LLEGA - Quiere jugar en la consola ps con el juego call_of_duty
# 28: Cliente 9 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego call_of_duty
# 33: Cliente 10 - LLEGA - Quiere jugar en la consola xbox con el juego fifa
# 33: Cliente 10 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego fifa
# 38: Cliente 11 - LLEGA - Quiere jugar en la consola ps con el juego call_of_duty
# 38: Cliente 11 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego call_of_duty
# 43: Cliente 12 - LLEGA - Quiere jugar en la consola xbox con el juego call_of_duty
# 43: Cliente 12 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego call_of_duty
# 44: Cliente 13 - LLEGA - Quiere jugar en la consola ps con el juego fifa
# 44: Cliente 13 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego fifa
# 45: Cliente 14 - LLEGA - Quiere jugar en la consola ps con el juego fifa
# 45: Cliente 14 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego fifa
# 48: Cliente 15 - LLEGA - Quiere jugar en la consola xbox con el juego call_of_duty
# 48: Cliente 15 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego call_of_duty
# 51: Cliente 16 - LLEGA - Quiere jugar en la consola xbox con el juego fifa
# 51: Cliente 16 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego fifa
# 52: Cliente 17 - LLEGA - Quiere jugar en la consola ps con el juego fifa
# 52: Cliente 17 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego fifa
# 56: Cliente 18 - LLEGA - Quiere jugar en la consola xbox con el juego call_of_duty
# 56: Cliente 18 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego call_of_duty
# 59: Cliente 19 - LLEGA - Quiere jugar en la consola ps con el juego fifa
# 59: Cliente 19 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego fifa
# 61: Cliente 1 - TERMINA JUEGO en ps_1
# 61: Cliente 1 - Cliente 1 PAGA 1 HORA
# 62: Cliente 20 - LLEGA - Quiere jugar en la consola xbox con el juego fifa
# 62: Cliente 20 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego fifa
# 63: Cliente 2 - TERMINA JUEGO en ps_2
# 63: Cliente 2 - Cliente 2 PAGA 1 HORA
# 67: Cliente 21 - LLEGA - Quiere jugar en la consola ps con el juego call_of_duty
# 67: Cliente 21 - Consola ps_1 ESTÁ DISPONIBLE para ps con el juego call_of_duty
# 67: Cliente 21 - COMIENZA JUEGO en ps_1
# 68: Cliente 3 - TERMINA JUEGO en xbox_1
# 68: Cliente 3 - Cliente 3 PAGA 1 HORA
# 68: Cliente 3 - Cliente 3 DECIDE QUEDARSE UNA HORA MÁS
# 71: Cliente 22 - LLEGA - Quiere jugar en la consola xbox con el juego fifa
# 71: Cliente 22 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego fifa
# 76: Cliente 23 - LLEGA - Quiere jugar en la consola xbox con el juego call_of_duty
# 76: Cliente 23 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego call_of_duty
# 78: Cliente 6 - TERMINA JUEGO en xbox_2
# 78: Cliente 6 - Cliente 6 PAGA 1 HORA
# 78: Cliente 6 - Cliente 6 DECIDE QUEDARSE UNA HORA MÁS
# 79: Cliente 24 - LLEGA - Quiere jugar en la consola ps con el juego call_of_duty
# 79: Cliente 24 - Consola ps_2 ESTÁ DISPONIBLE para ps con el juego call_of_duty
# 79: Cliente 24 - COMIENZA JUEGO en ps_2
# 80: Cliente 25 - LLEGA - Quiere jugar en la consola ps con el juego fifa
# 80: Cliente 25 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego fifa
# 84: Cliente 26 - LLEGA - Quiere jugar en la consola ps con el juego call_of_duty
# 84: Cliente 26 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego call_of_duty
# 89: Cliente 27 - LLEGA - Quiere jugar en la consola xbox con el juego call_of_duty
# 89: Cliente 27 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego call_of_duty
# 90: Cliente 28 - LLEGA - Quiere jugar en la consola xbox con el juego call_of_duty
# 90: Cliente 28 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego call_of_duty
# 93: Cliente 29 - LLEGA - Quiere jugar en la consola xbox con el juego fifa
# 93: Cliente 29 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego fifa
# 94: Cliente 30 - LLEGA - Quiere jugar en la consola xbox con el juego fifa
# 94: Cliente 30 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego fifa
# 97: Cliente 31 - LLEGA - Quiere jugar en la consola ps con el juego fifa
# 97: Cliente 31 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego fifa
# 99: Cliente 32 - LLEGA - Quiere jugar en la consola ps con el juego call_of_duty
# 99: Cliente 32 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego call_of_duty
# 100: Cliente 33 - LLEGA - Quiere jugar en la consola ps con el juego call_of_duty
# 100: Cliente 33 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego call_of_duty
# 102: Cliente 34 - LLEGA - Quiere jugar en la consola ps con el juego fifa
# 102: Cliente 34 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego fifa
# 103: Cliente 35 - LLEGA - Quiere jugar en la consola xbox con el juego fifa
# 103: Cliente 35 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego fifa
# 105: Cliente 36 - LLEGA - Quiere jugar en la consola xbox con el juego fifa
# 105: Cliente 36 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego fifa
# 110: Cliente 37 - LLEGA - Quiere jugar en la consola xbox con el juego fifa
# 110: Cliente 37 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego fifa
# 113: Cliente 38 - LLEGA - Quiere jugar en la consola xbox con el juego call_of_duty
# 113: Cliente 38 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego call_of_duty
# 118: Cliente 39 - LLEGA - Quiere jugar en la consola xbox con el juego fifa
# 118: Cliente 39 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego fifa
# 120: Cliente 40 - LLEGA - Quiere jugar en la consola ps con el juego call_of_duty
# 120: Cliente 40 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego call_of_duty
# 125: Cliente 41 - LLEGA - Quiere jugar en la consola ps con el juego fifa
# 125: Cliente 41 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego fifa
# 126: Cliente 42 - LLEGA - Quiere jugar en la consola ps con el juego fifa
# 126: Cliente 42 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego fifa
# 127: Cliente 21 - TERMINA JUEGO en ps_1
# 127: Cliente 21 - Cliente 21 PAGA 1 HORA
# 127: Cliente 43 - LLEGA - Quiere jugar en la consola xbox con el juego fifa
# 127: Cliente 43 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego fifa
# 128: Cliente 3 - Cliente 3 PAGA OTRA HORA. TOTAL = 2 HORA(S)
# 130: Cliente 44 - LLEGA - Quiere jugar en la consola xbox con el juego fifa
# 130: Cliente 44 - Consola xbox_1 ESTÁ DISPONIBLE para xbox con el juego fifa
# 130: Cliente 44 - COMIENZA JUEGO en xbox_1
# 135: Cliente 45 - LLEGA - Quiere jugar en la consola xbox con el juego fifa
# 135: Cliente 45 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego fifa
# 138: Cliente 6 - Cliente 6 PAGA OTRA HORA. TOTAL = 2 HORA(S)
# 139: Cliente 24 - TERMINA JUEGO en ps_2
# 139: Cliente 24 - Cliente 24 PAGA 1 HORA
# 139: Cliente 24 - Cliente 24 DECIDE QUEDARSE UNA HORA MÁS
# 139: Cliente 46 - LLEGA - Quiere jugar en la consola ps con el juego fifa
# 139: Cliente 46 - Consola ps_1 ESTÁ DISPONIBLE para ps con el juego fifa
# 139: Cliente 46 - COMIENZA JUEGO en ps_1
# 142: Cliente 47 - LLEGA - Quiere jugar en la consola xbox con el juego call_of_duty
# 142: Cliente 47 - Consola xbox_2 ESTÁ DISPONIBLE para xbox con el juego call_of_duty
# 142: Cliente 47 - COMIENZA JUEGO en xbox_2
# 143: Cliente 48 - LLEGA - Quiere jugar en la consola ps con el juego fifa
# 143: Cliente 48 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego fifa
# 146: Cliente 49 - LLEGA - Quiere jugar en la consola ps con el juego fifa
# 146: Cliente 49 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego fifa
# 148: Cliente 50 - LLEGA - Quiere jugar en la consola xbox con el juego fifa
# 148: Cliente 50 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego fifa
# 150: Cliente 51 - LLEGA - Quiere jugar en la consola xbox con el juego call_of_duty
# 150: Cliente 51 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego call_of_duty
# 151: Cliente 52 - LLEGA - Quiere jugar en la consola xbox con el juego fifa
# 151: Cliente 52 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego fifa
# 156: Cliente 53 - LLEGA - Quiere jugar en la consola ps con el juego fifa
# 156: Cliente 53 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego fifa
# 158: Cliente 54 - LLEGA - Quiere jugar en la consola xbox con el juego call_of_duty
# 158: Cliente 54 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego call_of_duty
# 160: Cliente 55 - LLEGA - Quiere jugar en la consola xbox con el juego fifa
# 160: Cliente 55 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego fifa
# 164: Cliente 56 - LLEGA - Quiere jugar en la consola ps con el juego call_of_duty
# 164: Cliente 56 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego call_of_duty
# 168: Cliente 57 - LLEGA - Quiere jugar en la consola xbox con el juego call_of_duty
# 168: Cliente 57 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego call_of_duty
# 170: Cliente 58 - LLEGA - Quiere jugar en la consola ps con el juego call_of_duty
# 170: Cliente 58 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego call_of_duty
# 171: Cliente 59 - LLEGA - Quiere jugar en la consola ps con el juego call_of_duty
# 171: Cliente 59 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego call_of_duty
# 172: Cliente 60 - LLEGA - Quiere jugar en la consola xbox con el juego fifa
# 172: Cliente 60 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego fifa
# 177: Cliente 61 - LLEGA - Quiere jugar en la consola ps con el juego fifa
# 177: Cliente 61 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego fifa
# 182: Cliente 62 - LLEGA - Quiere jugar en la consola ps con el juego fifa
# 182: Cliente 62 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego fifa
# 183: Cliente 63 - LLEGA - Quiere jugar en la consola ps con el juego fifa
# 183: Cliente 63 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego fifa
# 187: Cliente 64 - LLEGA - Quiere jugar en la consola xbox con el juego call_of_duty
# 187: Cliente 64 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego call_of_duty
# 190: Cliente 44 - TERMINA JUEGO en xbox_1
# 190: Cliente 44 - Cliente 44 PAGA 1 HORA
# 190: Cliente 44 - Cliente 44 DECIDE QUEDARSE UNA HORA MÁS
# 190: Cliente 65 - LLEGA - Quiere jugar en la consola xbox con el juego call_of_duty
# 190: Cliente 65 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego call_of_duty
# 193: Cliente 66 - LLEGA - Quiere jugar en la consola xbox con el juego call_of_duty
# 193: Cliente 66 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego call_of_duty
# 194: Cliente 67 - LLEGA - Quiere jugar en la consola xbox con el juego fifa
# 194: Cliente 67 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego fifa
# 199: Cliente 24 - Cliente 24 PAGA OTRA HORA. TOTAL = 2 HORA(S)
# 199: Cliente 46 - TERMINA JUEGO en ps_1
# 199: Cliente 46 - Cliente 46 PAGA 1 HORA
# 199: Cliente 68 - LLEGA - Quiere jugar en la consola ps con el juego call_of_duty
# 199: Cliente 68 - Consola ps_1 ESTÁ DISPONIBLE para ps con el juego call_of_duty
# 199: Cliente 68 - COMIENZA JUEGO en ps_1
# 202: Cliente 47 - TERMINA JUEGO en xbox_2
# 202: Cliente 47 - Cliente 47 PAGA 1 HORA
# 202: Cliente 69 - LLEGA - Quiere jugar en la consola ps con el juego fifa
# 202: Cliente 69 - Consola ps_2 ESTÁ DISPONIBLE para ps con el juego fifa
# 202: Cliente 69 - COMIENZA JUEGO en ps_2
# 205: Cliente 70 - LLEGA - Quiere jugar en la consola ps con el juego call_of_duty
# 205: Cliente 70 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego call_of_duty
# 210: Cliente 71 - LLEGA - Quiere jugar en la consola ps con el juego call_of_duty
# 210: Cliente 71 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego call_of_duty
# 212: Cliente 72 - LLEGA - Quiere jugar en la consola xbox con el juego fifa
# 212: Cliente 72 - Consola xbox_2 ESTÁ DISPONIBLE para xbox con el juego fifa
# 212: Cliente 72 - COMIENZA JUEGO en xbox_2
# 217: Cliente 73 - LLEGA - Quiere jugar en la consola ps con el juego call_of_duty
# 217: Cliente 73 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego call_of_duty
# 222: Cliente 74 - LLEGA - Quiere jugar en la consola ps con el juego call_of_duty
# 222: Cliente 74 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego call_of_duty
# 225: Cliente 75 - LLEGA - Quiere jugar en la consola xbox con el juego call_of_duty
# 225: Cliente 75 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego call_of_duty
# 226: Cliente 76 - LLEGA - Quiere jugar en la consola xbox con el juego call_of_duty
# 226: Cliente 76 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego call_of_duty
# 227: Cliente 77 - LLEGA - Quiere jugar en la consola xbox con el juego fifa
# 227: Cliente 77 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego fifa
# 229: Cliente 78 - LLEGA - Quiere jugar en la consola xbox con el juego call_of_duty
# 229: Cliente 78 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego call_of_duty
# 230: Cliente 79 - LLEGA - Quiere jugar en la consola ps con el juego fifa
# 230: Cliente 79 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego fifa
# 233: Cliente 80 - LLEGA - Quiere jugar en la consola ps con el juego call_of_duty
# 233: Cliente 80 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego call_of_duty
# 234: Cliente 81 - LLEGA - Quiere jugar en la consola xbox con el juego call_of_duty
# 234: Cliente 81 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego call_of_duty
# 237: Cliente 82 - LLEGA - Quiere jugar en la consola ps con el juego fifa
# 237: Cliente 82 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego fifa
# 240: Cliente 83 - LLEGA - Quiere jugar en la consola xbox con el juego fifa
# 240: Cliente 83 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego fifa
# 242: Cliente 84 - LLEGA - Quiere jugar en la consola ps con el juego call_of_duty
# 242: Cliente 84 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego call_of_duty
# 244: Cliente 85 - LLEGA - Quiere jugar en la consola xbox con el juego call_of_duty
# 244: Cliente 85 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego call_of_duty
# 247: Cliente 86 - LLEGA - Quiere jugar en la consola ps con el juego fifa
# 247: Cliente 86 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego fifa
# 248: Cliente 87 - LLEGA - Quiere jugar en la consola xbox con el juego fifa
# 248: Cliente 87 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego fifa
# 250: Cliente 44 - Cliente 44 PAGA OTRA HORA. TOTAL = 2 HORA(S)
# 252: Cliente 88 - LLEGA - Quiere jugar en la consola xbox con el juego call_of_duty
# 252: Cliente 88 - Consola xbox_1 ESTÁ DISPONIBLE para xbox con el juego call_of_duty
# 252: Cliente 88 - COMIENZA JUEGO en xbox_1
# 254: Cliente 89 - LLEGA - Quiere jugar en la consola ps con el juego fifa
# 254: Cliente 89 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego fifa
# 257: Cliente 90 - LLEGA - Quiere jugar en la consola xbox con el juego fifa
# 257: Cliente 90 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego fifa
# 259: Cliente 68 - TERMINA JUEGO en ps_1
# 259: Cliente 68 - Cliente 68 PAGA 1 HORA
# 260: Cliente 91 - LLEGA - Quiere jugar en la consola xbox con el juego fifa
# 260: Cliente 91 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego fifa
# 262: Cliente 69 - TERMINA JUEGO en ps_2
# 262: Cliente 69 - Cliente 69 PAGA 1 HORA
# 263: Cliente 92 - LLEGA - Quiere jugar en la consola ps con el juego call_of_duty
# 263: Cliente 92 - Consola ps_1 ESTÁ DISPONIBLE para ps con el juego call_of_duty
# 263: Cliente 92 - COMIENZA JUEGO en ps_1
# 264: Cliente 93 - LLEGA - Quiere jugar en la consola xbox con el juego call_of_duty
# 264: Cliente 93 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego call_of_duty
# 268: Cliente 94 - LLEGA - Quiere jugar en la consola ps con el juego call_of_duty
# 268: Cliente 94 - Consola ps_2 ESTÁ DISPONIBLE para ps con el juego call_of_duty
# 268: Cliente 94 - COMIENZA JUEGO en ps_2
# 271: Cliente 95 - LLEGA - Quiere jugar en la consola ps con el juego call_of_duty
# 271: Cliente 95 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego call_of_duty
# 272: Cliente 72 - TERMINA JUEGO en xbox_2
# 272: Cliente 72 - Cliente 72 PAGA 1 HORA
# 272: Cliente 72 - Cliente 72 DECIDE QUEDARSE UNA HORA MÁS
# 276: Cliente 96 - LLEGA - Quiere jugar en la consola xbox con el juego call_of_duty
# 276: Cliente 96 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego call_of_duty
# 279: Cliente 97 - LLEGA - Quiere jugar en la consola xbox con el juego fifa
# 279: Cliente 97 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego fifa
# 284: Cliente 98 - LLEGA - Quiere jugar en la consola xbox con el juego call_of_duty
# 284: Cliente 98 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego call_of_duty
# 288: Cliente 99 - LLEGA - Quiere jugar en la consola xbox con el juego fifa
# 288: Cliente 99 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego fifa
# 292: Cliente 100 - LLEGA - Quiere jugar en la consola xbox con el juego fifa
# 292: Cliente 100 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego fifa
# 296: Cliente 101 - LLEGA - Quiere jugar en la consola ps con el juego call_of_duty
# 296: Cliente 101 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego call_of_duty
# 298: Cliente 102 - LLEGA - Quiere jugar en la consola xbox con el juego call_of_duty
# 298: Cliente 102 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego call_of_duty
# 302: Cliente 103 - LLEGA - Quiere jugar en la consola xbox con el juego fifa
# 302: Cliente 103 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego fifa
# 304: Cliente 104 - LLEGA - Quiere jugar en la consola ps con el juego call_of_duty
# 304: Cliente 104 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego call_of_duty
# 305: Cliente 105 - LLEGA - Quiere jugar en la consola ps con el juego call_of_duty
# 305: Cliente 105 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego call_of_duty
# 307: Cliente 106 - LLEGA - Quiere jugar en la consola ps con el juego fifa
# 307: Cliente 106 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego fifa
# 309: Cliente 107 - LLEGA - Quiere jugar en la consola xbox con el juego fifa
# 309: Cliente 107 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego fifa
# 312: Cliente 88 - TERMINA JUEGO en xbox_1
# 312: Cliente 88 - Cliente 88 PAGA 1 HORA
# 312: Cliente 88 - Cliente 88 DECIDE QUEDARSE UNA HORA MÁS
# 313: Cliente 108 - LLEGA - Quiere jugar en la consola xbox con el juego call_of_duty
# 313: Cliente 108 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego call_of_duty
# 315: Cliente 109 - LLEGA - Quiere jugar en la consola ps con el juego fifa
# 315: Cliente 109 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego fifa
# 319: Cliente 110 - LLEGA - Quiere jugar en la consola ps con el juego fifa
# 319: Cliente 110 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego fifa
# 320: Cliente 111 - LLEGA - Quiere jugar en la consola ps con el juego fifa
# 320: Cliente 111 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego fifa
# 322: Cliente 112 - LLEGA - Quiere jugar en la consola xbox con el juego call_of_duty
# 322: Cliente 112 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego call_of_duty
# 323: Cliente 92 - TERMINA JUEGO en ps_1
# 323: Cliente 92 - Cliente 92 PAGA 1 HORA
# 327: Cliente 113 - LLEGA - Quiere jugar en la consola xbox con el juego fifa
# 327: Cliente 113 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego fifa
# 328: Cliente 94 - TERMINA JUEGO en ps_2
# 328: Cliente 94 - Cliente 94 PAGA 1 HORA
# 331: Cliente 114 - LLEGA - Quiere jugar en la consola ps con el juego call_of_duty
# 331: Cliente 114 - Consola ps_1 ESTÁ DISPONIBLE para ps con el juego call_of_duty
# 331: Cliente 114 - COMIENZA JUEGO en ps_1
# 332: Cliente 72 - Cliente 72 PAGA OTRA HORA. TOTAL = 2 HORA(S)
# 333: Cliente 115 - LLEGA - Quiere jugar en la consola xbox con el juego call_of_duty
# 333: Cliente 115 - Consola xbox_2 ESTÁ DISPONIBLE para xbox con el juego call_of_duty
# 333: Cliente 115 - COMIENZA JUEGO en xbox_2
# 336: Cliente 116 - LLEGA - Quiere jugar en la consola ps con el juego call_of_duty
# 336: Cliente 116 - Consola ps_2 ESTÁ DISPONIBLE para ps con el juego call_of_duty
# 336: Cliente 116 - COMIENZA JUEGO en ps_2
# 339: Cliente 117 - LLEGA - Quiere jugar en la consola ps con el juego fifa
# 339: Cliente 117 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego fifa
# 341: Cliente 118 - LLEGA - Quiere jugar en la consola xbox con el juego fifa
# 341: Cliente 118 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego fifa
# 342: Cliente 119 - LLEGA - Quiere jugar en la consola xbox con el juego call_of_duty
# 342: Cliente 119 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego call_of_duty
# 347: Cliente 120 - LLEGA - Quiere jugar en la consola xbox con el juego call_of_duty
# 347: Cliente 120 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego call_of_duty
# 349: Cliente 121 - LLEGA - Quiere jugar en la consola xbox con el juego call_of_duty
# 349: Cliente 121 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego call_of_duty
# 354: Cliente 122 - LLEGA - Quiere jugar en la consola xbox con el juego call_of_duty
# 354: Cliente 122 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego call_of_duty
# 357: Cliente 123 - LLEGA - Quiere jugar en la consola xbox con el juego call_of_duty
# 357: Cliente 123 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego call_of_duty
# 362: Cliente 124 - LLEGA - Quiere jugar en la consola ps con el juego call_of_duty
# 362: Cliente 124 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego call_of_duty
# 365: Cliente 125 - LLEGA - Quiere jugar en la consola xbox con el juego call_of_duty
# 365: Cliente 125 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego call_of_duty
# 369: Cliente 126 - LLEGA - Quiere jugar en la consola xbox con el juego call_of_duty
# 369: Cliente 126 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego call_of_duty
# 372: Cliente 88 - Cliente 88 PAGA OTRA HORA. TOTAL = 2 HORA(S)
# 373: Cliente 127 - LLEGA - Quiere jugar en la consola ps con el juego fifa
# 373: Cliente 127 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego fifa
# 378: Cliente 128 - LLEGA - Quiere jugar en la consola ps con el juego fifa
# 378: Cliente 128 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego fifa
# 380: Cliente 129 - LLEGA - Quiere jugar en la consola xbox con el juego fifa
# 380: Cliente 129 - Consola xbox_1 ESTÁ DISPONIBLE para xbox con el juego fifa
# 380: Cliente 129 - COMIENZA JUEGO en xbox_1
# 383: Cliente 130 - LLEGA - Quiere jugar en la consola xbox con el juego call_of_duty
# 383: Cliente 130 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego call_of_duty
# 387: Cliente 131 - LLEGA - Quiere jugar en la consola xbox con el juego call_of_duty
# 387: Cliente 131 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego call_of_duty
# 390: Cliente 132 - LLEGA - Quiere jugar en la consola xbox con el juego call_of_duty
# 390: Cliente 132 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego call_of_duty
# 391: Cliente 114 - TERMINA JUEGO en ps_1
# 391: Cliente 114 - Cliente 114 PAGA 1 HORA
# 393: Cliente 115 - TERMINA JUEGO en xbox_2
# 393: Cliente 115 - Cliente 115 PAGA 1 HORA
# 393: Cliente 115 - Cliente 115 DECIDE QUEDARSE UNA HORA MÁS
# 394: Cliente 133 - LLEGA - Quiere jugar en la consola ps con el juego call_of_duty
# 394: Cliente 133 - Consola ps_1 ESTÁ DISPONIBLE para ps con el juego call_of_duty
# 394: Cliente 133 - COMIENZA JUEGO en ps_1
# 395: Cliente 134 - LLEGA - Quiere jugar en la consola ps con el juego fifa
# 395: Cliente 134 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego fifa
# 396: Cliente 116 - TERMINA JUEGO en ps_2
# 396: Cliente 116 - Cliente 116 PAGA 1 HORA
# 397: Cliente 135 - LLEGA - Quiere jugar en la consola ps con el juego fifa
# 397: Cliente 135 - Consola ps_2 ESTÁ DISPONIBLE para ps con el juego fifa
# 397: Cliente 135 - COMIENZA JUEGO en ps_2
# 399: Cliente 136 - LLEGA - Quiere jugar en la consola xbox con el juego fifa
# 399: Cliente 136 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego fifa
# 403: Cliente 137 - LLEGA - Quiere jugar en la consola xbox con el juego call_of_duty
# 403: Cliente 137 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego call_of_duty
# 408: Cliente 138 - LLEGA - Quiere jugar en la consola ps con el juego fifa
# 408: Cliente 138 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego fifa
# 409: Cliente 139 - LLEGA - Quiere jugar en la consola ps con el juego call_of_duty
# 409: Cliente 139 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego call_of_duty
# 413: Cliente 140 - LLEGA - Quiere jugar en la consola ps con el juego fifa
# 413: Cliente 140 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego fifa
# 414: Cliente 141 - LLEGA - Quiere jugar en la consola xbox con el juego fifa
# 414: Cliente 141 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego fifa
# 417: Cliente 142 - LLEGA - Quiere jugar en la consola xbox con el juego call_of_duty
# 417: Cliente 142 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego call_of_duty
# 422: Cliente 143 - LLEGA - Quiere jugar en la consola xbox con el juego fifa
# 422: Cliente 143 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego fifa
# 426: Cliente 144 - LLEGA - Quiere jugar en la consola ps con el juego call_of_duty
# 426: Cliente 144 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego call_of_duty
# 430: Cliente 145 - LLEGA - Quiere jugar en la consola ps con el juego call_of_duty
# 430: Cliente 145 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego call_of_duty
# 435: Cliente 146 - LLEGA - Quiere jugar en la consola xbox con el juego call_of_duty
# 435: Cliente 146 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego call_of_duty
# 439: Cliente 147 - LLEGA - Quiere jugar en la consola xbox con el juego call_of_duty
# 439: Cliente 147 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego call_of_duty
# 440: Cliente 129 - TERMINA JUEGO en xbox_1
# 440: Cliente 129 - Cliente 129 PAGA 1 HORA
# 440: Cliente 148 - LLEGA - Quiere jugar en la consola xbox con el juego fifa
# 440: Cliente 148 - Consola xbox_1 ESTÁ DISPONIBLE para xbox con el juego fifa
# 440: Cliente 148 - COMIENZA JUEGO en xbox_1
# 445: Cliente 149 - LLEGA - Quiere jugar en la consola xbox con el juego call_of_duty
# 445: Cliente 149 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego call_of_duty
# 449: Cliente 150 - LLEGA - Quiere jugar en la consola xbox con el juego fifa
# 449: Cliente 150 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego fifa
# 451: Cliente 151 - LLEGA - Quiere jugar en la consola xbox con el juego call_of_duty
# 451: Cliente 151 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego call_of_duty
# 453: Cliente 115 - Cliente 115 PAGA OTRA HORA. TOTAL = 2 HORA(S)
# 454: Cliente 133 - TERMINA JUEGO en ps_1
# 454: Cliente 133 - Cliente 133 PAGA 1 HORA
# 454: Cliente 152 - LLEGA - Quiere jugar en la consola ps con el juego fifa
# 454: Cliente 152 - Consola ps_1 ESTÁ DISPONIBLE para ps con el juego fifa
# 454: Cliente 152 - COMIENZA JUEGO en ps_1
# 456: Cliente 153 - LLEGA - Quiere jugar en la consola xbox con el juego call_of_duty
# 456: Cliente 153 - Consola xbox_2 ESTÁ DISPONIBLE para xbox con el juego call_of_duty
# 456: Cliente 153 - COMIENZA JUEGO en xbox_2
# 457: Cliente 135 - TERMINA JUEGO en ps_2
# 457: Cliente 135 - Cliente 135 PAGA 1 HORA
# 460: Cliente 154 - LLEGA - Quiere jugar en la consola xbox con el juego fifa
# 460: Cliente 154 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego fifa
# 463: Cliente 155 - LLEGA - Quiere jugar en la consola ps con el juego call_of_duty
# 463: Cliente 155 - Consola ps_2 ESTÁ DISPONIBLE para ps con el juego call_of_duty
# 463: Cliente 155 - COMIENZA JUEGO en ps_2
# 466: Cliente 156 - LLEGA - Quiere jugar en la consola xbox con el juego call_of_duty
# 466: Cliente 156 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego call_of_duty
# 470: Cliente 157 - LLEGA - Quiere jugar en la consola xbox con el juego call_of_duty
# 470: Cliente 157 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego call_of_duty
# 473: Cliente 158 - LLEGA - Quiere jugar en la consola xbox con el juego call_of_duty
# 473: Cliente 158 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego call_of_duty
# 474: Cliente 159 - LLEGA - Quiere jugar en la consola ps con el juego call_of_duty
# 474: Cliente 159 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego call_of_duty
# 479: Cliente 160 - LLEGA - Quiere jugar en la consola ps con el juego fifa
# 479: Cliente 160 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego fifa
# 483: Cliente 161 - LLEGA - Quiere jugar en la consola xbox con el juego call_of_duty
# 483: Cliente 161 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego call_of_duty
# 485: Cliente 162 - LLEGA - Quiere jugar en la consola xbox con el juego fifa
# 485: Cliente 162 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego fifa
# 487: Cliente 163 - LLEGA - Quiere jugar en la consola xbox con el juego fifa
# 487: Cliente 163 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego fifa
# 490: Cliente 164 - LLEGA - Quiere jugar en la consola ps con el juego fifa
# 490: Cliente 164 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego fifa
# 492: Cliente 165 - LLEGA - Quiere jugar en la consola xbox con el juego fifa
# 492: Cliente 165 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego fifa
# 497: Cliente 166 - LLEGA - Quiere jugar en la consola xbox con el juego call_of_duty
# 497: Cliente 166 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego call_of_duty
# 500: Cliente 148 - TERMINA JUEGO en xbox_1
# 500: Cliente 148 - Cliente 148 PAGA 1 HORA
# 501: Cliente 167 - LLEGA - Quiere jugar en la consola xbox con el juego fifa
# 501: Cliente 167 - Consola xbox_1 ESTÁ DISPONIBLE para xbox con el juego fifa
# 501: Cliente 167 - COMIENZA JUEGO en xbox_1
# 504: Cliente 168 - LLEGA - Quiere jugar en la consola xbox con el juego fifa
# 504: Cliente 168 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego fifa
# 508: Cliente 169 - LLEGA - Quiere jugar en la consola xbox con el juego fifa
# 508: Cliente 169 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego fifa
# 510: Cliente 170 - LLEGA - Quiere jugar en la consola ps con el juego call_of_duty
# 510: Cliente 170 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego call_of_duty
# 512: Cliente 171 - LLEGA - Quiere jugar en la consola ps con el juego call_of_duty
# 512: Cliente 171 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego call_of_duty
# 514: Cliente 152 - TERMINA JUEGO en ps_1
# 514: Cliente 152 - Cliente 152 PAGA 1 HORA
# 516: Cliente 153 - TERMINA JUEGO en xbox_2
# 516: Cliente 153 - Cliente 153 PAGA 1 HORA
# 517: Cliente 172 - LLEGA - Quiere jugar en la consola xbox con el juego call_of_duty
# 517: Cliente 172 - Consola xbox_2 ESTÁ DISPONIBLE para xbox con el juego call_of_duty
# 517: Cliente 172 - COMIENZA JUEGO en xbox_2
# 520: Cliente 173 - LLEGA - Quiere jugar en la consola ps con el juego fifa
# 520: Cliente 173 - Consola ps_1 ESTÁ DISPONIBLE para ps con el juego fifa
# 520: Cliente 173 - COMIENZA JUEGO en ps_1
# 522: Cliente 174 - LLEGA - Quiere jugar en la consola xbox con el juego fifa
# 522: Cliente 174 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego fifa
# 523: Cliente 155 - TERMINA JUEGO en ps_2
# 523: Cliente 155 - Cliente 155 PAGA 1 HORA
# 523: Cliente 155 - Cliente 155 DECIDE QUEDARSE UNA HORA MÁS
# 524: Cliente 175 - LLEGA - Quiere jugar en la consola ps con el juego fifa
# 524: Cliente 175 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego fifa
# 528: Cliente 176 - LLEGA - Quiere jugar en la consola xbox con el juego call_of_duty
# 528: Cliente 176 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego call_of_duty
# 529: Cliente 177 - LLEGA - Quiere jugar en la consola ps con el juego call_of_duty
# 529: Cliente 177 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego call_of_duty
# 533: Cliente 178 - LLEGA - Quiere jugar en la consola ps con el juego fifa
# 533: Cliente 178 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego fifa
# 538: Cliente 179 - LLEGA - Quiere jugar en la consola ps con el juego call_of_duty
# 538: Cliente 179 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego call_of_duty
# 543: Cliente 180 - LLEGA - Quiere jugar en la consola ps con el juego fifa
# 543: Cliente 180 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego fifa
# 545: Cliente 181 - LLEGA - Quiere jugar en la consola ps con el juego fifa
# 545: Cliente 181 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego fifa
# 548: Cliente 182 - LLEGA - Quiere jugar en la consola xbox con el juego call_of_duty
# 548: Cliente 182 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego call_of_duty
# 552: Cliente 183 - LLEGA - Quiere jugar en la consola xbox con el juego call_of_duty
# 552: Cliente 183 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego call_of_duty
# 557: Cliente 184 - LLEGA - Quiere jugar en la consola xbox con el juego call_of_duty
# 557: Cliente 184 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego call_of_duty
# 561: Cliente 167 - TERMINA JUEGO en xbox_1
# 561: Cliente 167 - Cliente 167 PAGA 1 HORA
# 561: Cliente 167 - Cliente 167 DECIDE QUEDARSE UNA HORA MÁS
# 562: Cliente 185 - LLEGA - Quiere jugar en la consola xbox con el juego call_of_duty
# 562: Cliente 185 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego call_of_duty
# 563: Cliente 186 - LLEGA - Quiere jugar en la consola ps con el juego fifa
# 563: Cliente 186 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego fifa
# 566: Cliente 187 - LLEGA - Quiere jugar en la consola ps con el juego fifa
# 566: Cliente 187 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego fifa
# 571: Cliente 188 - LLEGA - Quiere jugar en la consola xbox con el juego call_of_duty
# 571: Cliente 188 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego call_of_duty
# 576: Cliente 189 - LLEGA - Quiere jugar en la consola xbox con el juego call_of_duty
# 576: Cliente 189 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego call_of_duty
# 577: Cliente 172 - TERMINA JUEGO en xbox_2
# 577: Cliente 172 - Cliente 172 PAGA 1 HORA
# 580: Cliente 173 - TERMINA JUEGO en ps_1
# 580: Cliente 173 - Cliente 173 PAGA 1 HORA
# 580: Cliente 190 - LLEGA - Quiere jugar en la consola xbox con el juego call_of_duty
# 580: Cliente 190 - Consola xbox_2 ESTÁ DISPONIBLE para xbox con el juego call_of_duty
# 580: Cliente 190 - COMIENZA JUEGO en xbox_2
# 581: Cliente 191 - LLEGA - Quiere jugar en la consola ps con el juego call_of_duty
# 581: Cliente 191 - Consola ps_1 ESTÁ DISPONIBLE para ps con el juego call_of_duty
# 581: Cliente 191 - COMIENZA JUEGO en ps_1
# 583: Cliente 155 - Cliente 155 PAGA OTRA HORA. TOTAL = 2 HORA(S)
# 585: Cliente 192 - LLEGA - Quiere jugar en la consola xbox con el juego call_of_duty
# 585: Cliente 192 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego call_of_duty
# 589: Cliente 193 - LLEGA - Quiere jugar en la consola ps con el juego call_of_duty
# 589: Cliente 193 - Consola ps_2 ESTÁ DISPONIBLE para ps con el juego call_of_duty
# 589: Cliente 193 - COMIENZA JUEGO en ps_2
# 592: Cliente 194 - LLEGA - Quiere jugar en la consola ps con el juego call_of_duty
# 592: Cliente 194 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego call_of_duty
# 597: Cliente 195 - LLEGA - Quiere jugar en la consola xbox con el juego call_of_duty
# 597: Cliente 195 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego call_of_duty
# 599: Cliente 196 - LLEGA - Quiere jugar en la consola xbox con el juego call_of_duty
# 599: Cliente 196 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego call_of_duty
# 600: Cliente 197 - LLEGA - Quiere jugar en la consola ps con el juego call_of_duty
# 600: Cliente 197 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego call_of_duty
# 603: Cliente 198 - LLEGA - Quiere jugar en la consola xbox con el juego call_of_duty
# 603: Cliente 198 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego call_of_duty
# 604: Cliente 199 - LLEGA - Quiere jugar en la consola ps con el juego fifa
# 604: Cliente 199 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego fifa
# 609: Cliente 200 - LLEGA - Quiere jugar en la consola ps con el juego call_of_duty
# 609: Cliente 200 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego call_of_duty
# 611: Cliente 201 - LLEGA - Quiere jugar en la consola ps con el juego call_of_duty
# 611: Cliente 201 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego call_of_duty
# 613: Cliente 202 - LLEGA - Quiere jugar en la consola xbox con el juego call_of_duty
# 613: Cliente 202 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego call_of_duty
# 617: Cliente 203 - LLEGA - Quiere jugar en la consola xbox con el juego call_of_duty
# 617: Cliente 203 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego call_of_duty
# 621: Cliente 167 - Cliente 167 PAGA OTRA HORA. TOTAL = 2 HORA(S)
# 621: Cliente 204 - LLEGA - Quiere jugar en la consola ps con el juego call_of_duty
# 621: Cliente 204 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego call_of_duty
# 626: Cliente 205 - LLEGA - Quiere jugar en la consola ps con el juego fifa
# 626: Cliente 205 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego fifa
# 630: Cliente 206 - LLEGA - Quiere jugar en la consola xbox con el juego call_of_duty
# 630: Cliente 206 - Consola xbox_1 ESTÁ DISPONIBLE para xbox con el juego call_of_duty
# 630: Cliente 206 - COMIENZA JUEGO en xbox_1
# 633: Cliente 207 - LLEGA - Quiere jugar en la consola xbox con el juego call_of_duty
# 633: Cliente 207 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego call_of_duty
# 637: Cliente 208 - LLEGA - Quiere jugar en la consola xbox con el juego call_of_duty
# 637: Cliente 208 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego call_of_duty
# 640: Cliente 190 - TERMINA JUEGO en xbox_2
# 640: Cliente 190 - Cliente 190 PAGA 1 HORA
# 641: Cliente 191 - TERMINA JUEGO en ps_1
# 641: Cliente 191 - Cliente 191 PAGA 1 HORA
# 642: Cliente 209 - LLEGA - Quiere jugar en la consola xbox con el juego call_of_duty
# 642: Cliente 209 - Consola xbox_2 ESTÁ DISPONIBLE para xbox con el juego call_of_duty
# 642: Cliente 209 - COMIENZA JUEGO en xbox_2
# 644: Cliente 210 - LLEGA - Quiere jugar en la consola ps con el juego call_of_duty
# 644: Cliente 210 - Consola ps_1 ESTÁ DISPONIBLE para ps con el juego call_of_duty
# 644: Cliente 210 - COMIENZA JUEGO en ps_1
# 648: Cliente 211 - LLEGA - Quiere jugar en la consola ps con el juego call_of_duty
# 648: Cliente 211 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego call_of_duty
# 649: Cliente 193 - TERMINA JUEGO en ps_2
# 649: Cliente 193 - Cliente 193 PAGA 1 HORA
# 652: Cliente 212 - LLEGA - Quiere jugar en la consola xbox con el juego fifa
# 652: Cliente 212 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego fifa
# 653: Cliente 213 - LLEGA - Quiere jugar en la consola ps con el juego call_of_duty
# 653: Cliente 213 - Consola ps_2 ESTÁ DISPONIBLE para ps con el juego call_of_duty
# 653: Cliente 213 - COMIENZA JUEGO en ps_2
# 657: Cliente 214 - LLEGA - Quiere jugar en la consola ps con el juego call_of_duty
# 657: Cliente 214 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego call_of_duty
# 659: Cliente 215 - LLEGA - Quiere jugar en la consola xbox con el juego fifa
# 659: Cliente 215 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego fifa
# 663: Cliente 216 - LLEGA - Quiere jugar en la consola xbox con el juego call_of_duty
# 663: Cliente 216 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego call_of_duty
# 664: Cliente 217 - LLEGA - Quiere jugar en la consola xbox con el juego call_of_duty
# 664: Cliente 217 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego call_of_duty
# 668: Cliente 218 - LLEGA - Quiere jugar en la consola ps con el juego fifa
# 668: Cliente 218 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego fifa
# 671: Cliente 219 - LLEGA - Quiere jugar en la consola ps con el juego fifa
# 671: Cliente 219 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego fifa
# 672: Cliente 220 - LLEGA - Quiere jugar en la consola ps con el juego call_of_duty
# 672: Cliente 220 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego call_of_duty
# 675: Cliente 221 - LLEGA - Quiere jugar en la consola ps con el juego fifa
# 675: Cliente 221 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego fifa
# 676: Cliente 222 - LLEGA - Quiere jugar en la consola xbox con el juego call_of_duty
# 676: Cliente 222 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego call_of_duty
# 680: Cliente 223 - LLEGA - Quiere jugar en la consola ps con el juego fifa
# 680: Cliente 223 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego fifa
# 685: Cliente 224 - LLEGA - Quiere jugar en la consola ps con el juego fifa
# 685: Cliente 224 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego fifa
# 686: Cliente 225 - LLEGA - Quiere jugar en la consola xbox con el juego fifa
# 686: Cliente 225 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego fifa
# 690: Cliente 206 - TERMINA JUEGO en xbox_1
# 690: Cliente 206 - Cliente 206 PAGA 1 HORA
# 690: Cliente 206 - Cliente 206 DECIDE QUEDARSE UNA HORA MÁS
# 691: Cliente 226 - LLEGA - Quiere jugar en la consola ps con el juego call_of_duty
# 691: Cliente 226 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego call_of_duty
# 695: Cliente 227 - LLEGA - Quiere jugar en la consola xbox con el juego fifa
# 695: Cliente 227 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego fifa
# 698: Cliente 228 - LLEGA - Quiere jugar en la consola ps con el juego fifa
# 698: Cliente 228 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego fifa
# 701: Cliente 229 - LLEGA - Quiere jugar en la consola xbox con el juego call_of_duty
# 701: Cliente 229 - SE VA POR FALTA DE CONSOLA DISPONIBLE - xbox con el juego call_of_duty
# 702: Cliente 209 - TERMINA JUEGO en xbox_2
# 702: Cliente 209 - Cliente 209 PAGA 1 HORA
# 704: Cliente 210 - TERMINA JUEGO en ps_1
# 704: Cliente 210 - Cliente 210 PAGA 1 HORA
# 705: Cliente 230 - LLEGA - Quiere jugar en la consola ps con el juego call_of_duty
# 705: Cliente 230 - Consola ps_1 ESTÁ DISPONIBLE para ps con el juego call_of_duty
# 705: Cliente 230 - COMIENZA JUEGO en ps_1
# 706: Cliente 231 - LLEGA - Quiere jugar en la consola ps con el juego call_of_duty
# 706: Cliente 231 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego call_of_duty
# 711: Cliente 232 - LLEGA - Quiere jugar en la consola xbox con el juego call_of_duty
# 711: Cliente 232 - Consola xbox_2 ESTÁ DISPONIBLE para xbox con el juego call_of_duty
# 711: Cliente 232 - COMIENZA JUEGO en xbox_2
# 713: Cliente 213 - TERMINA JUEGO en ps_2
# 713: Cliente 213 - Cliente 213 PAGA 1 HORA
# 715: Cliente 233 - LLEGA - Quiere jugar en la consola ps con el juego fifa
# 715: Cliente 233 - Consola ps_2 ESTÁ DISPONIBLE para ps con el juego fifa
# 715: Cliente 233 - COMIENZA JUEGO en ps_2
# 718: Cliente 234 - LLEGA - Quiere jugar en la consola ps con el juego call_of_duty
# 718: Cliente 234 - SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con el juego call_of_duty

# %% [markdown]
# ### DATAFRAME DEL CLIENTE

# %%
# Crear el perfil del cliente
lista_clientes = []
for c in sistema.clientes:
    lista_clientes.append({
        "id": c.id,
        "tipo_consola": c.tipo_consola,
        "juego": c.juego,
        "paciente": c.paciente,
        "atendido": c.atendido,
        "costo": c.costo
    })
dfclientes = pd.DataFrame(lista_clientes)

# Mostrar el perfil de un cliente específico
dfclientes.loc[dfclientes["id"] == 2, :]
# Out:
#    id tipo_consola juego  paciente  atendido  costo
# 1   2           ps  fifa      True      True      1

# %% [markdown]
# ### DATAFRAME DE LOS EVENTOS

# %%
# Crear el DataFrame de eventos
lista_eventos = []
for c in sistema.clientes:
    lista_eventos.append(c.eventos)
dfeventos = pd.concat(lista_eventos)
dfeventos = dfeventos.reset_index()
dfeventos.drop(["index"], axis=1, inplace=True)
dfeventos
# Out:
#       id                                             evento  time
# 0      1  LLEGA - Quiere jugar en la consola ps con el j...     1
# 1      1  Consola ps_1 ESTÁ DISPONIBLE para ps con el ju...     1
# 2      1                             COMIENZA JUEGO en ps_1     1
# 3      1                              TERMINA JUEGO en ps_1    61
# 4      1                              Cliente 1 PAGA 1 HORA    61
# ..   ...                                                ...   ...
# 590  233  LLEGA - Quiere jugar en la consola ps con el j...   715
# 591  233  Consola ps_2 ESTÁ DISPONIBLE para ps con el ju...   715
# 592  233                             COMIENZA JUEGO en ps_2   715
# 593  234  LLEGA - Quiere jugar en la consola ps con el j...   718
# 594  234  SE VA POR FALTA DE CONSOLA DISPONIBLE - ps con...   718
#
# [595 rows x 3 columns]

# %% [markdown]
# #### 1. ¿Cuál fue la consola mas utilizada?

# %%
dfclientes["tipo_consola"].value_counts()
# Out:
# tipo_consola
# xbox    126
# ps      108
# Name: count, dtype: int64

# %% [markdown]
# #### 2. ¿Cuantas personas decidieron quedarse una hora más?¿Cuál es el probabilidad de que un cliente se quede 1h más?

# %%
dfeventos[dfeventos["evento"].str.contains("DECIDE QUEDARSE UNA HORA MÁS")]["id"].nunique()
# Out:
# 10

# %%
clientes_quedaron_mas = dfeventos[dfeventos["evento"].str.contains("DECIDE QUEDARSE UNA HORA MÁS")]["id"].nunique()
clientes_atendidos = dfclientes[dfclientes["atendido"] == True]["id"].nunique()

probabilidad_quedarse = clientes_quedaron_mas / clientes_atendidos
print(f"Probabilidad de que un cliente atendido se quede una hora más: {probabilidad_quedarse:.2%}")
# Out:
# Probabilidad de que un cliente atendido se quede una hora más: 29.41%

# %% [markdown]
# #### 3. ¿Cuál fue el juego más utilizado en cada tipo de consola?

# %%
dfclientes.groupby(["tipo_consola", "juego"])["id"].count().reset_index(name="uso_total").sort_values(["tipo_consola", "uso_total"], ascending=[True, False])
# Out:
#   tipo_consola         juego  uso_total
# 0           ps  call_of_duty         55
# 1           ps          fifa         53
# 2         xbox  call_of_duty         74
# 3         xbox          fifa         52

# %% [markdown]
# #### 4. ¿Qué porcentaje de los clientes fueron atendidos?

# %%
atendidos = dfclientes["atendido"].sum()
total_clientes = dfclientes.shape[0]
porcentaje_atendidos = (atendidos / total_clientes) * 100

print(f"Porcentaje de clientes atendidos: {porcentaje_atendidos:.2f}%")
# Out:
# Porcentaje de clientes atendidos: 14.53%

# %% [markdown]
# #### 5. ¿Qué consola tuvo la mayor cantidad de sesiones extendidas?

# %%
df_extra = dfeventos[dfeventos["evento"].str.contains("DECIDE QUEDARSE UNA HORA MÁS")]
df_extra.merge(dfclientes, on="id").groupby("tipo_consola")["id"].count().reset_index(name="extensiones")
# Out:
#   tipo_consola  extensiones
# 0           ps            2
# 1         xbox            8

# %% [markdown]
# #### 6. ¿Cuantos clientes no fueron atendidos?

# %%
total_clientes = dfclientes["id"].nunique()
print(f"Total de clientes: {total_clientes}")
# Out:
# Total de clientes: 234

# %%
clientes_atendidos = dfclientes[dfclientes["atendido"] == True]["id"].nunique()
print(f"Clientes atendidos: {clientes_atendidos}")
# Out:
# Clientes atendidos: 34

# %%
clientes_no_atendidos = total_clientes - clientes_atendidos

probabilidad_no_ser_atendido = clientes_no_atendidos / total_clientes

print(f"Cantidad de clientes que NO fueron atendidos: {clientes_no_atendidos}")
print(f"Probabilidad de que un cliente NO sea atendido: {probabilidad_no_ser_atendido:.2%}")
# Out:
# Cantidad de clientes que NO fueron atendidos: 175
# Probabilidad de que un cliente NO sea atendido: 74.15%
